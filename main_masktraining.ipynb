# %% [markdown]
# <a href="https://colab.research.google.com/github/haneefmohammad/Mask_Detection/blob/main/main_masktraining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from imutils import paths


from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Activation, Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset= r'/content/drive/My Drive/facemask-detector'

# %%
imagePaths=list(paths.list_images(dataset))
imagePaths
# Out:
# ['/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/417.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_292.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/86.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/442.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_25.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_73.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/151.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_245.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/185.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/353.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_71.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_105.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_232.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_175.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_156.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_76.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_216.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_67.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/398.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/66.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/88.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_272.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_152.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/30.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_128.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/243.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_194.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/392.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/393.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/242.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_226.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/395.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/24.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/19.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/227.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/109.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_311.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_112.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/65.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/326.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/365.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_133.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_42.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/286.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_302.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/307.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_107.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/194.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/191.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_81.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_299.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_113.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/223.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/248.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_36.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_154.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/281.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/301.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/87.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/164.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/319.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/161.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/412.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_38.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/39.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/423.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/454.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/232.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_86.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/254.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/93.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/28.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/127.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_98.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/197.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_122.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/70.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_239.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_93.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_188.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/259.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/409.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/325.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/119.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_191.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_115.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_14.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_134.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_181.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/427.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_278.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/29.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_219.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/347.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/178.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/455.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_185.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/169.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/339.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/171.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/278.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/316.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/267.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_303.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/291.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/328.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/117.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/49.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/298.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_74.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/145.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/133.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/330.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/386.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_21.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_258.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_135.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/456.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/4.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/115.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/450.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_223.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/226.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_227.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/348.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/263.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/315.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_312.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_207.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_153.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/159.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_70.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_197.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/224.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/91.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/237.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_209.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_266.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/14.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_189.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_124.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/57.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/317.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/451.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/7.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/34.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/463.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/83.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/464.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/101.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/260.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/335.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_54.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_202.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/99.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/179.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/375.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/275.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/355.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/63.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/168.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/52.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/73.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/214.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/428.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_30.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_80.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_155.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_39.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_280.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/405.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/458.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_306.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/269.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/186.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/204.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_161.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/9.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/173.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/336.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/389.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/96.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/217.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/234.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/12.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_231.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_82.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/74.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_144.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_308.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_109.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/478.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/288.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_118.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_60.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_186.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_173.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/118.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_56.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/13.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/384.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_12.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/37.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/337.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/477.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_160.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_281.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/280.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_119.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_208.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/399.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/287.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_16.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/475.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/157.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/206.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/158.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/229.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/363.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/276.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_142.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_92.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_200.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_263.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_137.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/244.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/430.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_177.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/146.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_64.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_132.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_294.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/383.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_165.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/77.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_230.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/443.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/142.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/256.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_141.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_162.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_79.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/312.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/240.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_125.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/318.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/181.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/239.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/2.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_184.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_5.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/469.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_298.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_211.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_4.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/166.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/422.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_205.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/447.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/452.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/349.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/16.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/26.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/132.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/42.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/210.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/15.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_96.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_296.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/208.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/79.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/426.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_295.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_136.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/111.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/300.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_72.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/466.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_224.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/172.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_314.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_13.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_304.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/139.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/400.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/321.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_317.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/302.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/437.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/476.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_149.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/61.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_77.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_40.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_221.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_193.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_114.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_41.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_241.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/445.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/438.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/341.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/67.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/198.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/374.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/424.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/271.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/340.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_285.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_273.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/372.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/175.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_315.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/441.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_316.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_157.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_145.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/246.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_215.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_204.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/58.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/156.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/122.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_318.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_121.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/177.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_90.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/92.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/323.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_147.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_168.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/329.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/414.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_270.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_7.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/112.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/1.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/27.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_103.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/367.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/20.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_291.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/95.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_106.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/306.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/187.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/282.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/135.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/404.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_234.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/397.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/3.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_198.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_237.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/201.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/310.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/193.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_66.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/0.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/211.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/160.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/149.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/266.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/106.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/394.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_287.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/410.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/265.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/261.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/391.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_32.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_238.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/411.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/130.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/110.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_174.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_100.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_127.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/148.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_267.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/64.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_229.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_301.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/11.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/141.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/354.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/114.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/294.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/364.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_171.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/289.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/401.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_95.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/440.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_277.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_220.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/436.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/62.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/76.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/407.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/45.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_69.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_131.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/98.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_150.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/390.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/56.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/480.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/22.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_269.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/388.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/207.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_138.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/32.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/174.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/262.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/10.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_85.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_257.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/284.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_182.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_23.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/362.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/285.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_187.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/293.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/387.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_126.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/44.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/425.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/138.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_94.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_45.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/94.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/338.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/221.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/322.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/252.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/216.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_271.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/215.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/163.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/379.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/212.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_139.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/17.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/40.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/54.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_210.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/48.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_178.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/448.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_99.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_120.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/154.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/153.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_117.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_284.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_140.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_249.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_251.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/327.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/108.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_243.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/155.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/309.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/213.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/297.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/102.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/36.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_255.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/131.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/378.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_158.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/125.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/350.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/80.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/258.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_199.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_180.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_260.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/368.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_84.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/251.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/344.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/376.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/419.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/89.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_31.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_276.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/453.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_253.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/104.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_123.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_59.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_3.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/373.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_97.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_2.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/247.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/231.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_254.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/143.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_37.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/255.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/385.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_116.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/299.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/46.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_148.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/359.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/439.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_179.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/225.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/120.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/140.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/360.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_130.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/462.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_170.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/457.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/270.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/124.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_240.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/402.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_17.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/50.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/460.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_151.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/468.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_83.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_164.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/249.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/31.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_18.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_169.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/406.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/188.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_309.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/420.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/116.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/465.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/33.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_65.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_246.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/6.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/459.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/134.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/351.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_43.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_58.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/18.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_196.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/192.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/176.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/53.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/augmented_image_87.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/without_mask/334.jpg',
# ...
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_258.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/198-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_89.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/206-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_251.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_256.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_121.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_127.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_3.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/349-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_106.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/438-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/431-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_36.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_154.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/187-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/416-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/346-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/221-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_206.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_88.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/293-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_34.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_280.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/74-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/259-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/368-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_110.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/405-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_7.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_2.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/243-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_286.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/215-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_35.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_69.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/417-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_205.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/475-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/148-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/283-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_222.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_68.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_165.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_67.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/229-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/317-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_187.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/80-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/439-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_203.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_27.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/478-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/45-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/471-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/286-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/335-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_60.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_217.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/244-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_52.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_189.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/278-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_96.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_29.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_262.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_303.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/480-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/345-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/369-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/273-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/232-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/93-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_79.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/326-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_167.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/476-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/23-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_156.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/91-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/343-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/185-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/463-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_14.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_288.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_133.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/432-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/342-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/394-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/200-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/285-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_145.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_44.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/82-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_125.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_129.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_235.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_30.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_316.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_120.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/288-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_111.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_86.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/457-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/276-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_310.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_134.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/256-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_212.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_287.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_48.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_115.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_277.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/332-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_113.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_92.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_103.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_97.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_144.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_177.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/477-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/40-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/19-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_308.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/32-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/161-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/50-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_218.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/62-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/384-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/269-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/204-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_140.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/47-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_108.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/36-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/272-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_76.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_300.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_142.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/291-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/73-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/225-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/78-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/2-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/203-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/446-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/262-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_31.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_118.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_91.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_175.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/362-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_28.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_49.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/182-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_311.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/282-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_202.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_228.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_261.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/77-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_57.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/451-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_84.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/3-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_139.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/pra3.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/92-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_197.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_24.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/59-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/270-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_22.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_194.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/464-with-mask.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/augmented_image_244.jpg',
#  '/content/drive/My Drive/facemask-detector/mask_dataset/with_mask/409-with-mask.jpg',
#  ...]

# %%
data = [ ]
labels = [ ]

# %%
for i in imagePaths:
    label=i.split(os.path.sep)[-2]
    labels.append(label)
    image=load_img(i,target_size=(224,224))
    image=img_to_array(image)
    image=preprocess_input(image)
    data.append(image)
data=np.array(data,dtype='float32')
labels=np.array(labels)

# %%
data.shape
# Out:
# (1379, 224, 224, 3)

# %%
labels
# Out:
# array(['without_mask', 'without_mask', 'without_mask', ..., 'with_mask',
#        'with_mask', 'with_mask'], dtype='<U12')

# %%
lb=LabelBinarizer()
labels=lb.fit_transform(labels)
labels=to_categorical(labels)

# %%
train_X,test_X,train_Y,test_Y=train_test_split(data,labels,test_size=0.20,stratify=labels,random_state=10)

# %%
train_X.shape
# Out:
# (1103, 224, 224, 3)

# %%
train_Y.shape
# Out:
# (1103, 2)

# %%
test_X.shape
# Out:
# (276, 224, 224, 3)

# %%
test_Y.shape
# Out:
# (276, 2)

# %%
aug=ImageDataGenerator(rotation_range=20,zoom_range=0.15,width_shift_range=0.2,height_shift_range=0.2,shear_range=0.15,horizontal_flip=True,vertical_flip=True,fill_mode='nearest')

# %%
baseModel=MobileNetV2(weights='imagenet',include_top=False,input_tensor=Input(shape=(224,224,3)))

# %%
baseModel.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 225, 225, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 112, 112, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 112, 112, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 112, 112, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 112, 112, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 112, 112, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 112, 112, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 112, 112, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 113, 113, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 56, 56, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 56, 56, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 56, 56, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 56, 56, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 56, 56, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 56, 56, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 56, 56, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 56, 56, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 56, 56, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 56, 56, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 56, 56, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 56, 56, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 56, 56, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 57, 57, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 28, 28, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 28, 28, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 28, 28, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 28, 28, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 28, 28, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 28, 28, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 28, 28, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 28, 28, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 28, 28, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 28, 28, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 28, 28, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 28, 28, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 28, 28, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 28, 28, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 29, 29, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 14, 14, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 14, 14, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 14, 14, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 14, 14, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 14, 14, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 14, 14, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 14, 14, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 14, 14, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 14, 14, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 14, 14, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 14, 14, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 14, 14, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 14, 14, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 14, 14, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 14, 14, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 14, 14, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 14, 14, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 14, 14, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 14, 14, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 14, 14, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 14, 14, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 14, 14, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 14, 14, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 14, 14, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 14, 14, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 14, 14, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 14, 14, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 14, 14, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 14, 14, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 14, 14, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 14, 14, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 14, 14, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 14, 14, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 15, 15, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 2,223,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
headModel=baseModel.output
headModel=AveragePooling2D(pool_size=(7,7))(headModel)
headModel=Flatten(name='Flatten')(headModel)
headModel=Dense(128,activation='relu')(headModel)
headModel=Dropout(0.5)(headModel)
headModel=Dense(2,activation='softmax')(headModel)

model=Model(inputs=baseModel.input,outputs=headModel)

# %%
for layer in baseModel.layers:
  layer.trainable=False

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 225, 225, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 112, 112, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 112, 112, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 112, 112, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 112, 112, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 112, 112, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 112, 112, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 112, 112, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 113, 113, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 56, 56, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 56, 56, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 56, 56, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 56, 56, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 56, 56, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 56, 56, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 56, 56, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 56, 56, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 56, 56, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 56, 56, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 56, 56, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 56, 56, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 56, 56, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 57, 57, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 28, 28, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 28, 28, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 28, 28, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 28, 28, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 28, 28, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 28, 28, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 28, 28, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 28, 28, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 28, 28, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 28, 28, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 28, 28, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 28, 28, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 28, 28, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 28, 28, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 29, 29, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 14, 14, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 14, 14, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 14, 14, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 14, 14, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 14, 14, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 14, 14, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 14, 14, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 14, 14, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 14, 14, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 14, 14, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 14, 14, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 14, 14, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 14, 14, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 14, 14, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 14, 14, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 14, 14, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 14, 14, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 14, 14, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 14, 14, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 14, 14, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 14, 14, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 14, 14, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 14, 14, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 14, 14, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 14, 14, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 14, 14, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 14, 14, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 14, 14, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 14, 14, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 14, 14, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 14, 14, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 14, 14, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 14, 14, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 15, 15, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 1, 1, 1280)   0           out_relu[0][0]
# __________________________________________________________________________________________________
# Flatten (Flatten)               (None, 1280)         0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          163968      Flatten[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 2)            258         dropout_2[0][0]
# ==================================================================================================
# Total params: 2,422,210
# Trainable params: 164,226
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________

# %%
learning_rate=0.001
Epochs=20
BS=12

opt=Adam(lr=learning_rate,decay=learning_rate/Epochs)
model.compile(loss='binary_crossentropy',optimizer=opt,metrics=['accuracy'])

H=model.fit(
    aug.flow(train_X,train_Y,batch_size=BS),
    steps_per_epoch=len(train_X)//BS,
    validation_data=(test_X,test_Y),
    validation_steps=len(test_X)//BS,
    epochs=Epochs
)

model.save(r'/content/drive/My Drive/facemask-detector\mobilenet_v2.model')
# Out:
# Epoch 1/20
# 91/91 [==============================] - 58s 640ms/step - loss: 0.0146 - accuracy: 0.9954 - val_loss: 0.0746 - val_accuracy: 0.9928
# Epoch 2/20
# 91/91 [==============================] - 57s 623ms/step - loss: 0.0474 - accuracy: 0.9899 - val_loss: 0.0659 - val_accuracy: 0.9891
# Epoch 3/20
# 91/91 [==============================] - 57s 627ms/step - loss: 0.0216 - accuracy: 0.9963 - val_loss: 0.0716 - val_accuracy: 0.9928
# Epoch 4/20
# 91/91 [==============================] - 58s 634ms/step - loss: 0.0406 - accuracy: 0.9890 - val_loss: 0.0650 - val_accuracy: 0.9928
# Epoch 5/20
# 91/91 [==============================] - 61s 666ms/step - loss: 0.0465 - accuracy: 0.9899 - val_loss: 0.0654 - val_accuracy: 0.9891
# Epoch 6/20
# 91/91 [==============================] - 58s 633ms/step - loss: 0.0163 - accuracy: 0.9936 - val_loss: 0.0637 - val_accuracy: 0.9891
# Epoch 7/20
# 91/91 [==============================] - 58s 632ms/step - loss: 0.0159 - accuracy: 0.9927 - val_loss: 0.0632 - val_accuracy: 0.9928
# Epoch 8/20
# 91/91 [==============================] - 58s 633ms/step - loss: 0.0277 - accuracy: 0.9899 - val_loss: 0.0761 - val_accuracy: 0.9891
# Epoch 9/20
# 91/91 [==============================] - 58s 638ms/step - loss: 0.0502 - accuracy: 0.9853 - val_loss: 0.0597 - val_accuracy: 0.9928
# Epoch 10/20
# 91/91 [==============================] - 57s 627ms/step - loss: 0.0264 - accuracy: 0.9899 - val_loss: 0.0471 - val_accuracy: 0.9928
# Epoch 11/20
# 91/91 [==============================] - 57s 627ms/step - loss: 0.0115 - accuracy: 0.9973 - val_loss: 0.0430 - val_accuracy: 0.9928
# Epoch 12/20
# 91/91 [==============================] - 57s 632ms/step - loss: 0.0107 - accuracy: 0.9973 - val_loss: 0.0535 - val_accuracy: 0.9891
# Epoch 13/20
# 91/91 [==============================] - 57s 631ms/step - loss: 0.0276 - accuracy: 0.9927 - val_loss: 0.0425 - val_accuracy: 0.9855
# Epoch 14/20
# 91/91 [==============================] - 58s 634ms/step - loss: 0.0123 - accuracy: 0.9963 - val_loss: 0.0331 - val_accuracy: 0.9928
# Epoch 15/20
# 91/91 [==============================] - 61s 665ms/step - loss: 0.0124 - accuracy: 0.9954 - val_loss: 0.0316 - val_accuracy: 0.9928
# Epoch 16/20
# 91/91 [==============================] - 57s 629ms/step - loss: 0.0180 - accuracy: 0.9936 - val_loss: 0.0227 - val_accuracy: 0.9928
# Epoch 17/20
# 91/91 [==============================] - 58s 634ms/step - loss: 0.0108 - accuracy: 0.9963 - val_loss: 0.0288 - val_accuracy: 0.9891
# Epoch 18/20
# 91/91 [==============================] - 57s 628ms/step - loss: 0.0116 - accuracy: 0.9963 - val_loss: 0.0371 - val_accuracy: 0.9928
# Epoch 19/20
# 91/91 [==============================] - 57s 630ms/step - loss: 0.0174 - accuracy: 0.9927 - val_loss: 0.0384 - val_accuracy: 0.9928
# Epoch 20/20
# 91/91 [==============================] - 58s 633ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.0386 - val_accuracy: 0.9928
# INFO:tensorflow:Assets written to: /content/drive/My Drive/facemask-detector\mobilenet_v2.model/assets

# %%
predict=model.predict(test_X,batch_size=BS)
predict=np.argmax(predict,axis=1)
print(classification_report(test_Y.argmax(axis=1),predict,target_names=lb.classes_))
# Out:
#               precision    recall  f1-score   support
#
#    with_mask       0.99      0.99      0.99       139
# without_mask       0.99      0.99      0.99       137
#
#     accuracy                           0.99       276
#    macro avg       0.99      0.99      0.99       276
# weighted avg       0.99      0.99      0.99       276
